# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np 
y=np.random.rand(10)
x =y*2

# %%
x
# Out:
# array([1.50090032, 1.74309011, 1.88517577, 0.00551338, 1.43236284,
#        0.08912027, 0.97555715, 0.82371113, 0.4272197 , 0.52809415])

# %%
plt.plot(y,x,'y')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'b')
plt.title('X vs Y')

plt.subplot(1,2,2)
plt.plot(y,x,'r')
plt.title('Y vs X')
# Out:
# Text(0.5, 1.0, 'Y vs X')

# %%
gif=plt.figure()

axe=gif.add_axes([0.1,0.1,0.8,0.8])#has to be in a list , range 0 to 1 .

axe.plot(x,y,'r-')
axe.set_xlabel('X line')
axe.set_ylabel('Y Line')
# Out:
# Text(0, 0.5, 'Y Line')

# %%
gif=plt.figure()

axe1=gif.add_axes([0.1,0.1,0.9,1])
axe1.set_title('Fig1')
axe1.plot(y,x)
axe2=gif.add_axes([0.8,0.2,0.8,0.5])
axe2.set_title('Fig2')
axe2.plot(x,y)

# %%
gif,axes =plt.subplots(nrows=1, ncols=2)

axes[0].plot(y,x)
axes[0].set_label('plot1')

axes[1].plot(x,y)
axes[1].set_label('plot2')

plt.tight_layout()

# %%
fig=plt.figure(figsize=(6,2))

axes=fig.add_axes([0,0,1,0.8])
axes.plot(x,y,'r',label='x vs y ')
axes.plot(y,x,'b',label='y vs x ')
axes.legend()

# %%
fig,gax = plt.subplots(nrows=1,ncols=2,figsize=(10,2))

gax[0].plot(x,y)
gax[0].set_title('X vs Y')
gax[0].set_xlabel('X')
gax[0].set_ylabel('Y')
gax[1].plot(y,x)
gax[1].set_title('Yvs X')
gax[1].set_xlabel('Y')
gax[1].set_ylabel('X')

plt.tight_layout()

# %%
fig.savefig('first_jpg.png')

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");
